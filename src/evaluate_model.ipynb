# %%
import tkinter as tk  
from tkinter import filedialog  
import torch

# %%
from functions import load_whole_model, load_image, preprocess_image, load_and_evaluate_model
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from functions import load_whole_model, load_image, preprocess_image, load_and_evaluate_model
#
# File ~/Desktop/projects/Python/sign-language_CNN/src/functions.py:8
#       6 import torch
#       7 from PIL import Image
# ----> 8 import torchvision.transforms as transforms
#       9 from torch.utils.data import TensorDataset, DataLoader
#      10 import torch.nn as nn
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/torchvision/__init__.py:6
#       3 from modulefinder import Module
#       5 import torch
# ----> 6 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils
#       8 from .extension import _HAS_OPS
#      10 try:
#
# File ~/anaconda3/envs/ml_env/lib/python3.9/site-packages/torchvision/models/__init__.py:2
#       1 from .alexnet import *
# ...

# %%
# # Open file dialog to choose image  
# root = tk.Tk()  
# root.withdraw()  
# image_path = filedialog.askopenfilename()  
#   
# # Load image  
# image = load_image(image_path)  
#   
# # Preprocess image  
# image = preprocess_image(image)  
#   
# # Load model  
# model = load_whole_model('../model/sign_mnist_classifier.pt')  
#   
# # Pass preprocessed image to model  
# output = model(image)  
#   
# # Get predicted class  
# _, predicted_class = torch.max(output.data, 1)  
#   
# print(f'Predicted class: {predicted_class.item()}')

# %%
load_and_evaluate_model("../dataset/sign_mnist_test_new.csv", "../model/sign_mnist_classifier.pt")
